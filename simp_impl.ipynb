# %% [markdown]
# # State Space Models: Mamba : Text to Video

# %%
import tqdm
from datasets import load_from_disk
from dotenv import load_dotenv
import os

load_dotenv()
dataset = load_from_disk(os.getenv("DATASET_PATH"))
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['movie_name', 'year', 'genre', 'yt_clip_title', 'yt_clip_link', 'movie_scene', 'subtitles', 'question', 'choices', 'answer_key', 'answer_key_position', 'question_category', 'hard_split', 'visual_reliance', 'videoID'],
#         num_rows: 298888
#     })
#     test: Dataset({
#         features: ['movie_name', 'year', 'genre', 'yt_clip_title', 'yt_clip_link', 'movie_scene', 'subtitles', 'question', 'choices', 'answer_key', 'answer_key_position', 'question_category', 'hard_split', 'visual_reliance', 'videoID'],
#         num_rows: 4941
#     })
# })

# %%
dataset.set_format(type="torch", columns=["movie_name", "yt_clip_title", "subtitles"])

# %%
from torch.utils.data import DataLoader

# Create your DataLoader
dataloader = DataLoader(
    dataset,
    batch_size=4,
    shuffle=True,
    collate_fn=custom_collate_fn # Optional: Use this to handle video frames/variable text lengths
)

# Iterate through your data
for batch in dataloader:
    # batch['input_ids'] is now a PyTorch Tensor
    print(batch.keys())
    break
